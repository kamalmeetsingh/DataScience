# %% [markdown]
# # Data Science
#
# ** some junk**
#
# some more text

# %%
1+1
# Out:
# [1] 2

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
employee<-read.csv("dataset/Employee_Data.csv", header=TRUE)

# %%
duration = employee$Work_hour_in_week
std_emp = sd(duration)
std_emp
# Out:
# [1] 12.34743

# %%
mean_emp = mean(duration)
mean_emp
# Out:
# [1] 40.43746

# %%
print(duration)
# Out:
#     [1] 40 13 40 40 40 40 16 45 50 40 80 40 30 50 40 45 35 40 50 45 60 20 40 40
#    [25] 40 40 40 60 80 40 52 44 40 40 15 40 40 25 38 40 43 40 50 40 35 40 38 40
#    [49] 40 43 40 30 60 55 60 40 40 40 48 40 40 40 40 45 58 40 40 40 50 40 32 40
#    [73] 70 40 20 40 40  2 22 40 30 40 40 48 40 35 40 50 40 50 40 40 25 35 40 50
#    [97] 60 48 40 40 40 60 50 40 40 40 32 40 40 40 40 40 50 25 40 50 50 40 56 41
#   [121] 40 60 40 50 35 40 28 40 40 40 60 40 35 50 36 40 60 35 20 40 40 40 30 40
#   [145] 40 30 24 24 40 40 38 40 40 35 45 46 40  2 60 50 20 40 40 40 40 40 42 40
#   [169] 16 20 40 40 40 50 40 25 40 40 12 65 38 40 45 40 42 40 40 50 50  1 28 40
#   [193] 40 45 24 40 40 55 40 40 40 40 50 40 35 40 36 60 35 12 40 40 40 40 40 60
#   [217] 40 50 55 40 40 40 40 20 35 40 10 50 20 40 40 38 42 40 55 40 38 50 70 40
#   [241] 40 20 50 20 40 35 45 34 60 40 40 40 30 40 20 40 40 30 45 40 40 60 12 40
#   [265] 40 75 24 40 45 40 40 24 98 35 40 40 40 40 40 48 15 40 45 42 40 40 60 45
# ...

# %%
pnorm(80, mean=72, sd=15.2, lower.tail=FALSE)
# Out:
# [1] 0.2993344

# %%
?mean

# %%
?pnorm

# %%
getwd()
# Out:
# [1] "/Users/kamalmeetsingh/DataScience/statistical-inferences"

# %%
movie<-read.csv("dataset/M2_Movie_Metadata.csv", header=TRUE)

# %%
movie
# Out:
#      color            director_name      num_critic_for_reviews duration
# 1    Color            James Cameron      723                    178
# 2    Color            Gore Verbinski     302                    169
# 3    Color            Sam Mendes         602                    148
# 4    Color            Christopher Nolan  813                    164
# 5                     Doug Walker         NA                     NA
# 6    Color            Andrew Stanton     462                    132
# 7    Color            Sam Raimi          392                    156
# 8    Color            Nathan Greno       324                    100
# 9    Color            Joss Whedon        635                    141
# 10   Color            David Yates        375                    153
# 11   Color            Zack Snyder        673                    183
# 12   Color            Bryan Singer       434                    169
# 13   Color            Marc Forster       403                    106
# ...

# %%
bw<-subset(movie, color == " Black and White")

# %%
bw
# Out:
#      color            director_name       num_critic_for_reviews duration
# 112   Black and White Michael Bay         191                    184
# 150   Black and White Lee Tamahori        264                    133
# 258   Black and White Martin Scorsese     267                    170
# 273   Black and White Michael Mann        174                    165
# 287   Black and White Martin Campbell     400                    144
# 302   Black and White Stefen Fangmeier    170                    104
# 394   Black and White Gary Ross           175                    140
# 480   Black and White                      31                     25
# 498   Black and White Rob Marshall        205                    118
# 521   Black and White Stephen Norrington  202                    110
# 605   Black and White Steven Spielberg    388                    146
# 665   Black and White Clint Eastwood      169                    130
# 692   Black and White Frank Miller        339                    102
# ...

# %%
?trimws()

# %%
trimws(movie$color)
# Out:
#    [1] "Color"           "Color"           "Color"           "Color"
#    [5] ""                "Color"           "Color"           "Color"
#    [9] "Color"           "Color"           "Color"           "Color"
#   [13] "Color"           "Color"           "Color"           "Color"
#   [17] "Color"           "Color"           "Color"           "Color"
#   [21] "Color"           "Color"           "Color"           "Color"
#   [25] "Color"           "Color"           "Color"           "Color"
#   [29] "Color"           "Color"           "Color"           "Color"
#   [33] "Color"           "Color"           "Color"           "Color"
#   [37] "Color"           "Color"           "Color"           "Color"
#   [41] "Color"           "Color"           "Color"           "Color"
#   [45] "Color"           "Color"           "Color"           "Color"
#   [49] "Color"           "Color"           "Color"           "Color"
#   [53] "Color"           "Color"           "Color"           "Color"
# ...

# %%
bw1<-subset(movie, trimws(color) == "Black and White")
bw1
# Out:
#      color            director_name       num_critic_for_reviews duration
# 112   Black and White Michael Bay         191                    184
# 150   Black and White Lee Tamahori        264                    133
# 258   Black and White Martin Scorsese     267                    170
# 273   Black and White Michael Mann        174                    165
# 287   Black and White Martin Campbell     400                    144
# 302   Black and White Stefen Fangmeier    170                    104
# 394   Black and White Gary Ross           175                    140
# 480   Black and White                      31                     25
# 498   Black and White Rob Marshall        205                    118
# 521   Black and White Stephen Norrington  202                    110
# 605   Black and White Steven Spielberg    388                    146
# 665   Black and White Clint Eastwood      169                    130
# 692   Black and White Frank Miller        339                    102
# ...
