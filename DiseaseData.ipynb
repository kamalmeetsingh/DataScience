# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
disease<-read.csv("dataset/M2_Disease_data.csv", header=TRUE)
disease
# Out:
#    Age   sex    timesupper ill onsetdate onsettime baked_hamburgur spinach
# 1  27    Male   2000       yes 19-Apr      30      yes             yes
# 2  38    Female 1830       yes 19-Apr      30      yes             yes
# 3  32    Male   1830       yes 19-Apr      30      yes             yes
# 4  36    Male   1930       yes 18-Apr    2230      yes             yes
# 5  42    Female 1930       yes 18-Apr    2230      yes             yes
# 6  22    Male   1930       yes 19-Apr     200      no              no
# 7  7     Male   2200       yes 19-Apr     100      no              no
# 8  17    Male   1900       yes 18-Jun    2300      yes             yes
# 9  2     Female 1930       yes 19-Apr     200      no              no
# 10 16    Male     NA       yes 19-Apr    1030      yes             yes
# 11 34    Male     NA       yes 19-Apr      30      no              no
# 12 19    Female   NA       yes 18-Apr    2215      yes             yes
# ...

# %%
disease$Age= as.numeric(disease$Age)
disease$Age
# Out:
#  [1] 18 26 22 25 29 13 36  8 11  7 24 10  8 35 34  6 22 39 12  9 36 17  9 20 37
# [26] 27 32 30 21 24  3 18 33 16  5 31 28 14 19 38  2  4 23  1 18 15

# %%
disease_update<-na.omit(disease)
disease_update
# Out:
#    Age sex    timesupper ill onsetdate onsettime baked_hamburgur spinach
# 1  18  Male   2000       yes 19-Apr      30      yes             yes
# 2  26  Female 1830       yes 19-Apr      30      yes             yes
# 3  22  Male   1830       yes 19-Apr      30      yes             yes
# 4  25  Male   1930       yes 18-Apr    2230      yes             yes
# 5  29  Female 1930       yes 18-Apr    2230      yes             yes
# 6  13  Male   1930       yes 19-Apr     200      no              no
# 7  36  Male   2200       yes 19-Apr     100      no              no
# 8   8  Male   1900       yes 18-Jun    2300      yes             yes
# 9  11  Female 1930       yes 19-Apr     200      no              no
# 14 35  Male   2200       yes 19-Apr     100      no              no
# 18 39  Male   2200       yes 19-Apr     100      no              no
# 21 36  Female 2200       yes 19-Apr     100      no              no
# 22 17  -1     2200       yes 19-Apr     100      no              no
# ...

# %%
disease$timesupper[is.na(disease$timesupper)] <- round(mean(disease$timesupper, na.rm = TRUE))
disease
# Out:
#    Age   sex    timesupper ill onsetdate onsettime baked_hamburgur spinach
# 1  27    Male   2000       yes 19-Apr      30      yes             yes
# 2  38    Female 1830       yes 19-Apr      30      yes             yes
# 3  32    Male   1830       yes 19-Apr      30      yes             yes
# 4  36    Male   1930       yes 18-Apr    2230      yes             yes
# 5  42    Female 1930       yes 18-Apr    2230      yes             yes
# 6  22    Male   1930       yes 19-Apr     200      no              no
# 7  7     Male   2200       yes 19-Apr     100      no              no
# 8  17    Male   1900       yes 18-Jun    2300      yes             yes
# 9  2     Female 1930       yes 19-Apr     200      no              no
# 10 16    Male   1982       yes 19-Apr    1030      yes             yes
# 11 34    Male   1982       yes 19-Apr      30      no              no
# 12 19    Female 1982       yes 18-Apr    2215      yes             yes
# ...

# %%
data_subset<-disease[c(7,8:20)]
data_subset<-ifelse(data_subset=='yes', 1,0)
barplot(data_subset)
# Out:
# plot without title

# %%
boxplot(disease$Age)
# Out:
# plot without title

# %%
plot(disease$sex)
# Out:
# plot without title
